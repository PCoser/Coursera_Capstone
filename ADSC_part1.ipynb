# %% [markdown]
# # Professional Cleaning Salesperson Assignment
# My client is a professional cleaning firm, specialized in restaurants. They are open new business and seeking to take new clients in Ottawa-ON. THey requested me to build a list of potencial clients to visit and offer their services. They have four salesperson and they want to assign them to different areas of the city. My job is to search for restaurants in Ottawa and group it in four areas to each salesperson visit.
# ## Data Collection
# The dataset is going to be collected using Foursquare API, using a area between two coordinates, that includes the city of Gatineau-QC. But, the dataset should contain only venues from Ottawa. The Dataset should contain the name of the venue, type of restaurant, GPS location and address.
#
# <b>Importing libraries</b>

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
from pandas.io.json import json_normalize # tranforming json file into a pandas dataframe library

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
print('Folium installed')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# folium                    0.5.0                      py_0    conda-forge
# Folium installed

# %%
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim  # module to convert an address into latitude and longitude values
print('Geopy installed')
print('Libraries imported.')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# geopy                     1.18.1                     py_0    conda-forge
# Geopy installed
# Libraries imported.

# %% [markdown]
# Setting the Foursquare API credentials

# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# <b>Setting the parameters to search for venues</b>
#
# In this part is deffined the area of search for venues indicated by latitude and longitute coordinates.
# The grid size sets the individual area for each request to Foursquare API

# %%
grid_size_h = 15
grid_size_w = 22
north_limit = 45.448042
south_limit = 45.310282
west_limit = -75.845952
east_limit = -75.564285

grid_height = (north_limit - south_limit)/grid_size_h
grid_width = (west_limit - east_limit)/grid_size_w
search_query = 'Restaurant'
intent = 'browse'
search_params = {
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
    'intent': intent,
    'query': search_query,
    'limit': 100,
    'v': VERSION
}

geolocator = Nominatim(user_agent="Foursquare")
search_count = 0

# %% [markdown]
# <b>Searching for venues at Foursquare</b>
#
# In this cell is the for loop to request venues in individual areas. Each areas has approximatelly 1km2.
# The dataset is build in this cell as well. So for each request the result is appended on the end of the dataframe.

# %%
dataframe = []
for lat in range(grid_size_h):
    for lng in range(grid_size_w):
        ne_lat = north_limit - (lat * grid_height)
        ne_long = west_limit - (lng * grid_width)
        se_lat = ne_lat - grid_height
        se_lng = ne_long + grid_width

        search_params.update({'ne': '{},{}'.format(ne_lat, ne_long),
                              'sw': '{},{}'.format(se_lat, se_lng)})
        
        results = requests.get('https://api.foursquare.com/v2/venues/search',params=search_params)
        if 'venues' in results.json()['response']:
            venues = results.json()['response']['venues']

            for venue in venues:
                if len(dataframe) == 0:
                    dataframe = json_normalize(venue)
                dataframe2 = json_normalize(venue)
                dataframe = pd.concat([dataframe,dataframe2])

        search_count += 1

        if search_count % 30 == 0:
            print('Searched: {}'.format(search_count))
# Out:
# Searched: 30
# Searched: 60
# Searched: 90
# Searched: 120
# Searched: 150
# Searched: 180
# Searched: 210
# Searched: 240
# Searched: 270
# Searched: 300
# Searched: 330

# %%
len(dataframe) #Chequing if the size of the dataframe matches with the number of venues
# Out:
# 181

# %% [markdown]
# <b>Formating the columns names</b>

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered = dataframe_filtered[['id','name','lat','lng','address','city','state','categories']]

# %% [markdown]
# <b>Removing duplicate inputs and inputs from Quebec</b>

# %%
dataframe_filtered.drop_duplicates(subset='id', keep='first', inplace=True)
dataframe_filtered = dataframe_filtered[dataframe_filtered.state != 'QC']

# %%
dataframe_filtered.reset_index(inplace=True) #Reseting index
dataframe_filtered.drop(labels='index',axis=1,inplace=True)

# %% [markdown]
# <b>Removing NaN</b>
#
# Some data is missing on address column, so, we can take the information of geographic coordinates to get the address of those venues.
# The values with 'NaN' is substituted by the address found on the coordinates.

# %%
for i in dataframe_filtered.index[pd.isnull(dataframe_filtered['address']) == True].tolist():
    location = (geolocator.reverse(str(dataframe_filtered.loc[i]['lat']) +','+ str(dataframe_filtered.loc[i]['lng'])))
    local = location[0].split(',')
    address = str(local[0]) + ',' + str(local[1])
    city  = local[-4]
    if str(local[-3]) == ' Ontario':
        province = 'ON'
    elif str(local[-3]) == ' Québec':
        province = 'QC'
    else:
        province = local[-3]
    dataframe_filtered.at[i, 'address'] = str(address)
    dataframe_filtered.at[i, 'city'] = str(city)
    dataframe_filtered.at[i, 'state'] = str(province)
    print(i, dataframe_filtered.loc[i]['lat'], dataframe_filtered.loc[i]['lng'], address, city, province)
# Out:
# 4 45.4393842495 -75.6273699762 La Cité collégiale, 801  Ottawa ON
# 6 45.42997 -75.69294 111, Murray Street  Ottawa ON
# 20 45.422136 -75.69912 157, Sparks Street  Ottawa ON
# 29 45.427654 -75.690132 372, Dalhousie Street  Ottawa ON
# 36 45.424597646 -75.6347759162 1054, Ogilvie Road  Ottawa ON
# 37 45.424679 -75.636918 Sleep Country, 1133  Ottawa ON
# 52 45.4193349434 -75.6996723544 129, Bank Street  Ottawa ON
# 73 45.418283 -75.612438 1552, Cyrville Road  Ottawa ON
# 75 45.409776 -75.77777 DoubleTree by Hilton Hotel Gatineau-Ottawa, 1170  Outaouais QC
# 96 45.4072064 -75.6862189 35, Linden Terrace  Ottawa ON
# 104 45.394624 -75.755414 322, Churchill Avenue North  Ottawa ON
# 113 45.3870584993 -75.7327157153 Carling TS, 1275  Ottawa ON
# 125 45.378407 -75.645932 1729, Walkley Road  Ottawa ON
# 126 45.3663488834 -75.7831763038 Lincoln Heights, Britannia Bay  Ottawa ON
# 140 45.355285 -75.805633 Jambo Restaurant, 69  Ottawa ON
# 144 45.3500088444 -75.7575040007 Algonquin College, 1385  Ottawa ON
# 148 45.353888 -75.653063 Montana's, 2216  Ottawa ON
# 152 45.344728 -75.72939 Alterno Savings, 1715  Ottawa ON
# 154 45.330186 -75.721913 Canada Post, Enterprise Avenue  Ottawa ON
# 160 45.327062 -75.719407 1969, Merivale Road  Ottawa ON

# %% [markdown]
# <b>Removing any input that is not from Ontario

# %%
dataframe_filtered = dataframe_filtered[dataframe_filtered.state == 'ON']
dataframe_filtered.reset_index(inplace=True) #Reseting index
dataframe_filtered.drop(labels='index',axis=1,inplace=True)

# %% [markdown]
# <b>Final dataframe from data acquisition

# %%
dataframe_filtered.shape
# Out:
# (161, 8)

# %%
dataframe_filtered
# Out:
#                            id  \
# 0    582670997d7fb761d064e9e9
# 1    4c0a619d7e3fc928ae70f382
# 2    4ba405edf964a520d07838e3
# 3    52d71865498e489acd17525d
# 4    4b5f23d4f964a5208ea829e3
# 5    58c098aa01f43341813efdd0
# 6    4b5347adf964a520949527e3
# 7    4b9c3786f964a520e95536e3
# 8    4b6f374bf964a520bde42ce3
# 9    4b61f2c4f964a520ea2c2ae3
# 10   4ec835a58b81dcfdc45e4b48
# 11   5914917aee628b793f8397a4
# 12   4b893bc1f964a520d22432e3
# 13   4c1e0804b4e62d7f0c9bdd93
# 14   4b0586e1f964a520e67222e3
# 15   4b0586dff964a5208e7222e3
# 16   4cfd7126ee9cb60c757a9aad
# 17   4b0586e1f964a520f27222e3
# 18   4b0c7aadf964a520053e23e3
# 19   51ffe401498eb0a0d9fc07ee
# 20   4b8717e7f964a52031b031e3
# 21   4b19cca2f964a52065e423e3
# 22   4afd6c11f964a520b82722e3
# 23   4b0586e1f964a520077322e3
# 24   4afd8a14f964a5206c2822e3
# 25   4d7c1887136bf04df027598d
# 26   4b0586dff964a520757222e3
# 27   5acfc71a89b06a5c99a75950
# 28   5886962c4bafb7091152ef81
# 29   4ea7382ef9f4e0745d968635
# ..                        ...
# 131  4b632639f964a52087662ae3
# 132  5911fb7e26659b44d9874ef6
# 133  4b940ed0f964a520dc6434e3
# 134  54234801498e45513286c069
# 135  4b1a94b3f964a520c0ec23e3
# 136  5a2156239de23b046858ee8f
# 137  5987c0ebf5e9d7084936fc79
# 138  4e24686b483b041af20918ab
# 139  4b50eb76f964a520da3827e3
# 140  4ea1e84f108182805215e5a0
# 141  4b7c6eddf964a52005932fe3
# 142  4b3a220bf964a520726125e3
# 143  4bca30f4937ca593505ca792
# 144  4b852f91f964a520dc4f31e3
# 145  5a0e38736a59502565172050
# 146  4b49225ef964a5204d6726e3
# 147  4be43c24bcef2d7f013e02e5
# 148  5703058a498e64f9e7fd6df7
# 149  5712b20a498e7956d965bf0f
# 150  4ca6127914c337049bf2bb3b
# 151  4f9ad049e4b0a3d1db1c2f9f
# 152  4b549bfdf964a52084c227e3
# 153  4b607d9df964a52061e929e3
# 154  591491ada0215b4825b3cefb
# 155  4dfe6211d22d056d59a7b6e8
# 156  58cc6b5c15fb433bd0f1dfe3
# 157  55a8243d498e67daf5b20444
# 158  5038da2ce4b0d3a7940003e8
# 159  4b2930fdf964a520b59a24e3
# 160  4b6219a0f964a52060352ae3
#
#                                                   name        lat        lng  \
# 0           Sutherland Restaurant Bar and Coffee House  45.443455 -75.670020
# 1                                           McDonald's  45.441750 -75.643841
# 2                              Pilo's Greek Restaurant  45.446167 -75.630297
# 3           Le restaurant-école Les Jardins de la Cité  45.439384 -75.627370
# 4                                              Navarra  45.429785 -75.693345
# 5                                              Sur-Lie  45.429970 -75.692940
# 6                                   Saffron Restaurant  45.430578 -75.681453
# 7                              Sitar Indian Restaurant  45.430496 -75.681453
# 8                                              Habesha  45.432539 -75.676591
# 9                                   Maskali Restaurant  45.429805 -75.665091
# 10                          Best Pizza and Restaurants  45.431778 -75.655870
# 11                         DQ Grill & Chill Restaurant  45.432291 -75.649505
# 12                                           Gabriel's  45.437362 -75.602734
# 13                                 73 North Restaurant  45.423101 -75.696786
# 14                                Courtyard Restaurant  45.426864 -75.693833
# 15                        Social Restaurant and Lounge  45.426623 -75.694212
# 16                            Parliamentary Restaurant  45.424660 -75.700414
# 17                          The Fish Market Restaurant  45.428132 -75.692374
# 18            Wasabi Japanese Restaurant and Sushi Bar  45.428710 -75.694240
# 19                               Centretown Restaurant  45.422136 -75.699120
# 20                                    Sante Restaurant  45.425474 -75.693228
# 21                                   Saigon Restaurant  45.429169 -75.692861
# 22                            Fairmont Château Laurier  45.426241 -75.694909
# 23                                           Wilfrid's  45.425161 -75.695216
# 24                                          Milestones  45.425466 -75.694232
# 25                 Sidedoor Contemporary Kitchen & Bar  45.427255 -75.693941
# 26                                            E18hteen  45.427437 -75.694046
# 27                              Norca Restaurant & Bar  45.426131 -75.687945
# 28                             Restaurant Kebab Prince  45.427654 -75.690132
# 29   Restaurant Jazzy (University Centre | Centre u...  45.422537 -75.683548
# ..                                                 ...        ...        ...
# 131                             Carling Wok Restaurant  45.362969 -75.787882
# 132                        DQ Grill & Chill Restaurant  45.363608 -75.790106
# 133                                            Wendy's  45.363739 -75.786848
# 134                             Asian Stars Restaurant  45.360008 -75.739433
# 135                                            Denny's  45.359613 -75.739346
# 136                    Wong's Palace Tavern Restaurant  45.356072 -75.802961
# 137                                   Jambo Restaurant  45.355285 -75.805633
# 138                                    Ikea Restaurant  45.350407 -75.784679
# 139                                         Milestones  45.352055 -75.783799
# 140                       Hendrix Restaurant Equipment  45.353984 -75.779649
# 141                           Restaurant International  45.350009 -75.757504
# 142                                          Chances R  45.350383 -75.758492
# 143              Sea King Shark Fin Seafood Restaurant  45.353157 -75.735163
# 144                                         McDonald's  45.348158 -75.731376
# 145                        Montana's Restaurant Ottawa  45.353888 -75.653063
# 146                                     KS On The Keys  45.353243 -75.652434
# 147                                            Mr. B's  45.354572 -75.649350
# 148                           some junkshit restaurant  45.344728 -75.729390
# 149                                Mandarin Restaurant  45.338837 -75.711174
# 150                                 Steel's Restaurant  45.330186 -75.721913
# 151                                 Cindy's Restaurant  45.332000 -75.706567
# 152                               Sukhothai Restaurant  45.320907 -75.835402
# 153                    Welcome Back Chinese Restaurant  45.322220 -75.831800
# 154                        DQ Grill & Chill Restaurant  45.323579 -75.828635
# 155                                   Gow's restaurant  45.328556 -75.816028
# 156                    Countryplace Chinese Restaurant  45.327062 -75.719407
# 157  Daily & Daily Food Equipment Sales - Service -...  45.325159 -75.724913
# 158                       The Pine Restaurant & Tavern  45.327908 -75.701381
# 159                                   Zolas Restaurant  45.318719 -75.840478
# 160           Haveli Indian Restaurant (Bells Corners)  45.318227 -75.840706
#
#                             address             city state  \
# 0              224 Beechwood Avenue           Ottawa    ON
# 1                  594 Montreal Rd.           Ottawa    ON
# 2                   876 Montreal Rd  Ottawa Division    ON
# 3           La Cité collégiale, 801           Ottawa    ON
# 4                     93 Murray St.           Ottawa    ON
# 5                111, Murray Street           Ottawa    ON
# 6                    426 Rideau St.           Ottawa    ON
# 7                    417 Rideau St.           Ottawa    ON
# 8                    574 Rideau St.           Ottawa    ON
# 9                     27 Selkirk St           Ottawa    ON
# 10                 295 McArthur Ave           Vanier    ON
# 11                 401 McArthur Ave           Ottawa    ON
# 12                2016 Ogilvie Road           Ottawa    ON
# 13                     73 Sparks St           Ottawa    ON
# 14                 21 George Street           Ottawa    ON
# 15                    537 Sussex Dr           Ottawa    ON
# 16                     Centre Block           Ottawa    ON
# 17                   54 York Street           Ottawa    ON
# 18                   41 Clarence St           Ottawa    ON
# 19               157, Sparks Street           Ottawa    ON
# 20                     45 Rideau St           Ottawa    ON
# 21                   85 Clarence St           Ottawa    ON
# 22                     1 Rideau St.           Ottawa    ON
# 23                     1 Rideau St.           Ottawa    ON
# 24          700 Sussex Dr  Unit 201           Ottawa    ON
# 25                       20 York St           Ottawa    ON
# 26                       18 York St           Ottawa    ON
# 27                   30 Daly Avenue           Ottawa    ON
# 28            372, Dalhousie Street           Ottawa    ON
# 29       85 University | Université           Ottawa    ON
# ..                              ...              ...   ...
# 131                2583 Carling Ave           Ottawa    ON
# 132                1451 Richmond Rd           Ottawa    ON
# 133                2545 Carling Ave           Ottawa    ON
# 134          1380 Clyde Ave, Unit B           Ottawa    ON
# 135                  1380 Clyde Ave           Nepean    ON
# 136                2961 Carling Ave           Ottawa    ON
# 137            Jambo Restaurant, 69           Ottawa    ON
# 138                   2685 Iris St.           Ottawa    ON
# 139                  1080 Baxter Rd           Ottawa    ON
# 140       1050 Baxter Road Unit #11           Ottawa    ON
# 141         Algonquin College, 1385           Ottawa    ON
# 142                  1371 Woodroffe           Ottawa    ON
# 143              1558 Merivale Road           Nepean    ON
# 144               1675 Merivale Rd.           Ottawa    ON
# 145                 Montana's, 2216           Ottawa    ON
# 146                   1029 Daze St.           Ottawa    ON
# 147                       2401 Bank           Ottawa    ON
# 148           Alterno Savings, 1715           Ottawa    ON
# 149              290 W Hunt Club Rd           Nepean    ON
# 150  Canada Post, Enterprise Avenue           Ottawa    ON
# 151            117-15 Capella Court           Ottawa    ON
# 152                134 Robertson Rd           Ottawa    ON
# 153               90 Robertson Road           Nepean    ON
# 154               2036 Robertson Rd           Ottawa    ON
# 155                  Northside Road    Bells Corners    ON
# 156             1969, Merivale Road           Ottawa    ON
# 157                 52 Cleopatra Dr           Nepean    ON
# 158      2259 Prince Of Wales Drive           Ottawa    ON
# 159               194 Robertson Rd.           Ottawa    ON
# 160              194 Robertson Road           Ottawa    ON
#
#                     categories
# 0               Breakfast Spot
# 1         Fast Food Restaurant
# 2             Greek Restaurant
# 3                   Restaurant
# 4           Spanish Restaurant
# 5            French Restaurant
# 6    Middle Eastern Restaurant
# 7            Indian Restaurant
# 8         Ethiopian Restaurant
# 9           African Restaurant
# 10                 Pizza Place
# 11        Fast Food Restaurant
# 12          Italian Restaurant
# 13   Middle Eastern Restaurant
# 14                  Restaurant
# 15     New American Restaurant
# 16                  Restaurant
# 17          Seafood Restaurant
# 18         Japanese Restaurant
# 19                  Restaurant
# 20            Asian Restaurant
# 21       Vietnamese Restaurant
# 22                       Hotel
# 23                  Restaurant
# 24                    Wine Bar
# 25            Tapas Restaurant
# 26           French Restaurant
# 27                  Restaurant
# 28          African Restaurant
# 29           College Cafeteria
# ..                         ...
# 131         Chinese Restaurant
# 132       Fast Food Restaurant
# 133       Fast Food Restaurant
# 134           Asian Restaurant
# 135                      Diner
# 136                 Restaurant
# 137         African Restaurant
# 138    Scandinavian Restaurant
# 139       Fast Food Restaurant
# 140         Miscellaneous Shop
# 141          French Restaurant
# 142                  BBQ Joint
# 143         Chinese Restaurant
# 144       Fast Food Restaurant
# 145        American Restaurant
# 146        American Restaurant
# 147         Italian Restaurant
# 148        American Restaurant
# 149                     Buffet
# 150             Breakfast Spot
# 151                      Diner
# 152            Thai Restaurant
# 153         Chinese Restaurant
# 154       Fast Food Restaurant
# 155         Chinese Restaurant
# 156         Chinese Restaurant
# 157                       None
# 158                 Restaurant
# 159         Italian Restaurant
# 160          Indian Restaurant
#
# [161 rows x 8 columns]

# %% [markdown]
# #### Map showing the venues location

# %%
address = '2701 Riverside Dr, Ottawa, ON'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

venues_map = folium.Map(location=[latitude, longitude], zoom_start=12) # generate map centred around the CEF

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=3,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <b>Uploading dataset to SQL IBM-DB2</b>

# %% [markdown]
# Import magic SQL

# %%
# !pip install ipython-sql
# %load_ext sql
print('Magic SQL activated')
# Out:
# Magic SQL activated

# %% [markdown]
# Connecting to IBM-DB2 database

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# 'Connected: zcd26955@BLUDB'

# %% [markdown]
# ### Sending dataframe to the cloud!!!

# %%
# %sql PERSIST dataframe_filtered
# Out:
#  * ibm_db_sa://zcd26955:***@dashdb-txn-sbox-yp-dal09-04.services.dal.bluemix.net:50000/BLUDB
# 'Persisted dataframe_filtered'
